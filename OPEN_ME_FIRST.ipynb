# %% [markdown]
# # Let's set up your envrionment

# %% [markdown]
# ### Import necessary libraries
# *(click the *play* button in the toolbar above to execute a cell)*

# %%
import json
import os
import shutil
import datetime
import pandas as pd

import ipywidgets as widgets

# %% [markdown]
# ### 1. Which section are you in?

# %%
student_section = widgets.Dropdown(
    options=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'],
    value='Monday',
    description='Section:',
    disabled=False,
)
student_section
# Out:
# Dropdown(description='Section:', options=('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'),…

# %%
student_section.value = "Tuesday"

# %%
student_section.value
# Out:
# 'Tuesday'

# %% [markdown]
# ### 2. What is your name?

# %%
student_name = "Reece VanDeWeghe"

# %% [markdown]
# ### 3. Set up postcell

# %%
# class_name     = "pythonfordatascience"
# class_name     = "pythonformlengineering"
class_name     = "python_for_financial_datascience"

class_time_period  = "2025_september"

# %%
#Set up template
if not os.path.isfile('postcell.conf'):
    shutil.copyfile('postcell.conf.bak', 'postcell.conf')

#Open config file
with open('postcell.conf', 'rt') as conf:
    parsedj = json.load(conf)
    #print(parsedj['student_id'])
    #print(parsedj['class_id'])
    
#Set student name
parsedj['student_id'] = student_name.strip().replace(' ', '_')

#Set class name
class_id = f"{class_time_period}_{student_section.value.lower()}_{class_name}"
parsedj['class_id'] = class_id

#Write config file
#TODO: change should_send_to_server to true, set default to be false in .bak file
with open('postcell.conf', 'wt') as conf:
    json.dump(parsedj, conf, indent=4, sort_keys=True)
    
# Confirm your config
with open('postcell.conf', 'rt') as conf:
    parsedj = json.load(conf)
    print(parsedj['student_id'])
    print(parsedj['class_id'])
# Out:
# Reece_VanDeWeghe
# 2025_september_tuesday_python_for_financial_datascience

# %% [markdown]
# ### 4. Install the postcell magic command

# %%
# %pip install postcell -U --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %reload_ext postcell
# %postcell register
# Out:
# PostCell loaded
# Loading config file from /Users/reecevdw/UChicago/FINM324/postcell.conf
# Registered user Reece_VanDeWeghe at https://postcell.io/post_cell

# %%
# %%postcell OPEN_ME_FIRST_HELLO
# "Reece is here"
# Out:
# Cell posted for evaluation
# 'Reece is here'

# %%
# %%postcell OPEN_ME_FIRST_EXPERIENCE
# "I have been programming since 8 years old."
# Out:
# Cell posted for evaluation
# 'I have been programming since 8 years old.'

# %% [markdown]
# ### Fun test, how fast is your machine?

# %%
# %%timeit
sum(range(1_000_000))
# Out:
# 8.92 ms ± 16.2 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Paste the numeric value from the previous cell, along with a general description of you machine, on the next line

# %%
# %%postcell OPEN_ME_FIRST_MACHINE_PERFORMANCE
# "Apple Macbook Pro M2 Max 64GB"
# Out:
# Cell posted for evaluation
# 'Apple Macbook Pro M2 Max 64GB'

# %% [markdown]
# ### 5. Install other packages
# Since this is a very introductory course, students will install some required packages here, rather than via a proper environments file.

# %%
# %pip install ipywidgets tqdm seaborn bokeh "altair[all]"
# Out:
# Requirement already satisfied: ipywidgets in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (8.1.7)
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting bokeh
#   Downloading bokeh-3.8.0-py3-none-any.whl.metadata (10 kB)
# Collecting altair[all]
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipywidgets) (9.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: Jinja2>=2.9 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from bokeh) (1.3.3)
# Collecting narwhals>=1.13 (from bokeh)
#   Downloading narwhals-2.6.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=16.8 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from bokeh) (25.0)
# Requirement already satisfied: pillow>=7.1.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from bokeh) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from bokeh) (6.5.2)
# Collecting xyzservices>=2021.09.1 (from bokeh)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: jsonschema>=3.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from altair[all]) (4.25.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from altair[all]) (4.15.0)
# Collecting altair-tiles>=0.3.0 (from altair[all])
#   Downloading altair_tiles-0.4.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting anywidget>=0.9.0 (from altair[all])
#   Downloading anywidget-0.9.18-py3-none-any.whl.metadata (8.9 kB)
# Collecting pyarrow>=11 (from altair[all])
#   Downloading pyarrow-21.0.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting vega-datasets>=0.9.0 (from altair[all])
#   Downloading vega_datasets-0.9.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting vegafusion>=1.6.6 (from vegafusion[embed]>=1.6.6; extra == "all"->altair[all])
#   Downloading vegafusion-2.0.3-cp39-abi3-macosx_11_0_arm64.whl.metadata (1.1 kB)
# Collecting vl-convert-python>=1.7.0 (from altair[all])
#   Downloading vl_convert_python-1.8.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting mercantile (from altair-tiles>=0.3.0->altair[all])
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting psygnal>=0.8.1 (from anywidget>=0.9.0->altair[all])
#   Downloading psygnal-0.14.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.0 kB)
# Requirement already satisfied: decorator in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from jsonschema>=3.0->altair[all]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from jsonschema>=3.0->altair[all]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from jsonschema>=3.0->altair[all]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from jsonschema>=3.0->altair[all]) (0.27.1)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Collecting arro3-core (from vegafusion>=1.6.6->vegafusion[embed]>=1.6.6; extra == "all"->altair[all])
#   Downloading arro3_core-0.6.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (363 bytes)
# Collecting click>=3.0 (from mercantile->altair-tiles>=0.3.0->altair[all])
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: executing>=1.2.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/miniconda3/envs/finm32500/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading bokeh-3.8.0-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 21.1 MB/s  0:00:00 eta 0:00:01
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 21.3 MB/s  0:00:00
# Downloading altair_tiles-0.4.0-py3-none-any.whl (9.1 kB)
# Downloading anywidget-0.9.18-py3-none-any.whl (220 kB)
# Downloading narwhals-2.6.0-py3-none-any.whl (408 kB)
# Downloading psygnal-0.14.2-cp313-cp313-macosx_11_0_arm64.whl (576 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 576.3/576.3 kB 20.2 MB/s  0:00:00
# Downloading pyarrow-21.0.0-cp313-cp313-macosx_12_0_arm64.whl (31.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 14.6 MB/s  0:00:02m0:00:0100:01
# Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
# Downloading vegafusion-2.0.3-cp39-abi3-macosx_11_0_arm64.whl (20.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 9.7 MB/s  0:00:026m0:00:0100:01
# Downloading vl_convert_python-1.8.0-cp37-abi3-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 10.2 MB/s  0:00:02 eta 0:00:01
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Downloading arro3_core-0.6.3-cp313-cp313-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.0 MB/s  0:00:00 eta 0:00:01
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Installing collected packages: xyzservices, vl-convert-python, tqdm, pyarrow, psygnal, narwhals, click, arro3-core, vegafusion, mercantile, vega-datasets, seaborn, bokeh, anywidget, altair, altair-tiles
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [altair-tiles] [altair]]on]python]
# Successfully installed altair-5.5.0 altair-tiles-0.4.0 anywidget-0.9.18 arro3-core-0.6.3 bokeh-3.8.0 click-8.3.0 mercantile-1.2.1 narwhals-2.6.0 psygnal-0.14.2 pyarrow-21.0.0 seaborn-0.13.2 tqdm-4.67.1 vega-datasets-0.9.0 vegafusion-2.0.3 vl-convert-python-1.8.0 xyzservices-2025.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# nb_conda: load conda environments in jupyter
# tqdm:     Add progress bars to Jupyter 
# seaborn:  A very popular charting library

# %conda install bokeh tqdm seaborn -y
# Out:
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/miniconda3/envs/finm32500
#
#   added / updated specs:
#     - bokeh
#     - seaborn
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-3.8.0                |  py313hca03da5_0         5.8 MB
#     bottleneck-1.4.2           |  py313ha35b7ea_0         125 KB
#     brotli-python-1.0.9        |  py313h313beb8_9         367 KB
#     contourpy-1.3.1            |  py313h48ca7d4_0         265 KB
#     fontconfig-2.15.0          |       h29935d0_0         225 KB
#     fonttools-4.59.2           |  py313h254cc4a_0         4.0 MB
#     jinja2-3.1.6               |  py313hca03da5_0         370 KB
#     jpeg-9f                    |       h2f69dba_0         220 KB
#     kiwisolver-1.4.8           |  py313h313beb8_0          67 KB
#     libopenblas-0.3.30         |       hf2bb037_0         4.1 MB
#     markupsafe-3.0.2           |  py313h80987f9_0          27 KB
#     matplotlib-base-3.10.6     |  py313h8596600_0         7.9 MB
#     narwhals-1.31.0            |  py313hca03da5_1         587 KB
#     numexpr-2.11.0             |  py313hf08b1b5_1         191 KB
#     numpy-2.3.3                |  py313h4bb6f22_0          10 KB
#     numpy-base-2.3.3           |  py313h23175f9_0         6.2 MB
#     pandas-2.3.2               |  py313h17050e6_0        14.1 MB
#     pyparsing-3.2.0            |  py313hca03da5_0         455 KB
#     python-dateutil-2.9.0post0 |  py313hca03da5_2         306 KB
#     python-tzdata-2025.2       |     pyhd3eb1b0_0         141 KB
#     pytz-2025.2                |  py313hca03da5_0         238 KB
#     pyyaml-6.0.2               |  py313h80987f9_0         200 KB
#     seaborn-0.13.2             |  py313hca03da5_3         726 KB
#     six-1.17.0                 |  py313hca03da5_0          39 KB
#     tornado-6.5.1              |  py313h80987f9_0         904 KB
#     xyzservices-2025.4.0       |  py313hca03da5_0          65 KB
#     yaml-0.2.5                 |       h1a28f6b_0          71 KB
#     zstd-1.5.7                 |       h817c040_0         460 KB
#     ------------------------------------------------------------
#                                            Total:        48.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                pkgs/main/osx-arm64::aom-3.6.0-h313beb8_0
#   blas               pkgs/main/osx-arm64::blas-1.0-openblas
#   bokeh              pkgs/main/osx-arm64::bokeh-3.8.0-py313hca03da5_0
#   bottleneck         pkgs/main/osx-arm64::bottleneck-1.4.2-py313ha35b7ea_0
#   brotli-python      pkgs/main/osx-arm64::brotli-python-1.0.9-py313h313beb8_9
#   cairo              pkgs/main/osx-arm64::cairo-1.18.4-h191e429_0
#   contourpy          pkgs/main/osx-arm64::contourpy-1.3.1-py313h48ca7d4_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   dav1d              pkgs/main/osx-arm64::dav1d-1.2.1-h80987f9_0
#   fontconfig         pkgs/main/osx-arm64::fontconfig-2.15.0-h29935d0_0
#   fonttools          pkgs/main/osx-arm64::fonttools-4.59.2-py313h254cc4a_0
#   freetype           pkgs/main/osx-arm64::freetype-2.13.3-h47d26ad_0
#   fribidi            pkgs/main/osx-arm64::fribidi-1.0.10-h1a28f6b_0
#   gettext            pkgs/main/osx-arm64::gettext-0.21.0-hbdbcc25_2
#   graphite2          pkgs/main/osx-arm64::graphite2-1.3.14-hc377ac9_1
#   harfbuzz           pkgs/main/osx-arm64::harfbuzz-10.2.0-he637ebf_1
#   icu                pkgs/main/osx-arm64::icu-73.1-h313beb8_0
#   jinja2             pkgs/main/osx-arm64::jinja2-3.1.6-py313hca03da5_0
#   jpeg               pkgs/main/osx-arm64::jpeg-9f-h2f69dba_0
#   kiwisolver         pkgs/main/osx-arm64::kiwisolver-1.4.8-py313h313beb8_0
#   lcms2              pkgs/main/osx-arm64::lcms2-2.16-he26ebf3_1
#   lerc               pkgs/main/osx-arm64::lerc-4.0.0-h313beb8_0
#   libavif            pkgs/main/osx-arm64::libavif-1.1.1-h80987f9_0
#   libdeflate         pkgs/main/osx-arm64::libdeflate-1.22-h80987f9_0
#   libgfortran        pkgs/main/osx-arm64::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       pkgs/main/osx-arm64::libgfortran5-11.3.0-h009349e_28
#   libglib            pkgs/main/osx-arm64::libglib-2.84.2-hdc2269c_0
#   libiconv           pkgs/main/osx-arm64::libiconv-1.16-h80987f9_3
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.30-hf2bb037_0
#   libpng             pkgs/main/osx-arm64::libpng-1.6.39-h80987f9_0
#   libtiff            pkgs/main/osx-arm64::libtiff-4.7.0-h91aec0a_0
#   libwebp-base       pkgs/main/osx-arm64::libwebp-base-1.3.2-h80987f9_1
#   libxml2            pkgs/main/osx-arm64::libxml2-2.13.8-h0b34f26_0
#   llvm-openmp        pkgs/main/osx-arm64::llvm-openmp-20.1.8-he822017_0
#   lz4-c              pkgs/main/osx-arm64::lz4-c-1.9.4-h313beb8_1
#   markupsafe         pkgs/main/osx-arm64::markupsafe-3.0.2-py313h80987f9_0
#   matplotlib-base    pkgs/main/osx-arm64::matplotlib-base-3.10.6-py313h8596600_0
#   narwhals           pkgs/main/osx-arm64::narwhals-1.31.0-py313hca03da5_1
#   numexpr            pkgs/main/osx-arm64::numexpr-2.11.0-py313hf08b1b5_1
#   numpy              pkgs/main/osx-arm64::numpy-2.3.3-py313h4bb6f22_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-2.3.3-py313h23175f9_0
#   openjpeg           pkgs/main/osx-arm64::openjpeg-2.5.2-hba36e21_1
#   packaging          pkgs/main/osx-arm64::packaging-25.0-py313hca03da5_0
#   pandas             pkgs/main/osx-arm64::pandas-2.3.2-py313h17050e6_0
#   pcre2              pkgs/main/osx-arm64::pcre2-10.42-hb066dcc_1
#   pillow             pkgs/main/osx-arm64::pillow-11.3.0-py313h6dd570d_0
#   pixman             pkgs/main/osx-arm64::pixman-0.46.4-h09dc60e_0
#   pyparsing          pkgs/main/osx-arm64::pyparsing-3.2.0-py313hca03da5_0
#   python-dateutil    pkgs/main/osx-arm64::python-dateutil-2.9.0post0-py313hca03da5_2
#   python-tzdata      pkgs/main/noarch::python-tzdata-2025.2-pyhd3eb1b0_0
#   pytz               pkgs/main/osx-arm64::pytz-2025.2-py313hca03da5_0
#   pyyaml             pkgs/main/osx-arm64::pyyaml-6.0.2-py313h80987f9_0
#   seaborn            pkgs/main/osx-arm64::seaborn-0.13.2-py313hca03da5_3
#   six                pkgs/main/osx-arm64::six-1.17.0-py313hca03da5_0
#   tornado            pkgs/main/osx-arm64::tornado-6.5.1-py313h80987f9_0
#   tqdm               pkgs/main/osx-arm64::tqdm-4.67.1-py313h7eb115d_0
#   xyzservices        pkgs/main/osx-arm64::xyzservices-2025.4.0-py313hca03da5_0
#   yaml               pkgs/main/osx-arm64::yaml-0.2.5-h1a28f6b_0
#   zstd               pkgs/main/osx-arm64::zstd-1.5.7-h817c040_0
#
#
#
# Downloading and Extracting Packages:
# pandas-2.3.2         | 14.1 MB   |                                       |   0%
# matplotlib-base-3.10 | 7.9 MB    |                                       |   0%
#
# numpy-base-2.3.3     | 6.2 MB    |                                       |   0%
#
#
# bokeh-3.8.0          | 5.8 MB    |                                       |   0%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    |                                       |   0%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    |                                       |   0%
#
#
#
#
#
# tornado-6.5.1        | 904 KB    |                                       |   0%
#
#
#
#
#
#
# seaborn-0.13.2       | 726 KB    |                                       |   0%
#
#
#
#
#
#
#
# narwhals-1.31.0      | 587 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 460 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 455 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.6         | 370 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 367 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 306 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 265 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2025.2          | 238 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 225 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9f              | 220 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 200 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.11.0       | 191 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-tzdata-2025.2 | 141 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bottleneck-1.4.2     | 125 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yaml-0.2.5           | 71 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# matplotlib-base-3.10 | 7.9 MB    |                                       |   0%
# matplotlib-base-3.10 | 7.9 MB    | 7                                     |   2%
# pandas-2.3.2         | 14.1 MB   |                                       |   0%
#
# numpy-base-2.3.3     | 6.2 MB    |                                       |   0%
#
#
# bokeh-3.8.0          | 5.8 MB    | 1                                     |   0%
# pandas-2.3.2         | 14.1 MB   | 5                                     |   1%
#
#
# pandas-2.3.2         | 14.1 MB   | 8                                     |   2%
# pandas-2.3.2         | 14.1 MB   | #3                                    |   4%
#
# numpy-base-2.3.3     | 6.2 MB    | #4                                    |   4%
# matplotlib-base-3.10 | 7.9 MB    | ######4                               |  18%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##                                    |   5%
#
# numpy-base-2.3.3     | 6.2 MB    | ###1                                  |   9%
# matplotlib-base-3.10 | 7.9 MB    | #######4                              |  20%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##5                                   |   7%
# pandas-2.3.2         | 14.1 MB   | #7                                    |   5%
# matplotlib-base-3.10 | 7.9 MB    | #########                             |  24%
#
# numpy-base-2.3.3     | 6.2 MB    | ###9                                  |  11%
#
#
# pandas-2.3.2         | 14.1 MB   | ###                                   |   8%
#
# numpy-base-2.3.3     | 6.2 MB    | #####5                                |  15%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | 1                                     |   0%
#
# numpy-base-2.3.3     | 6.2 MB    | ######7                               |  18%
# matplotlib-base-3.10 | 7.9 MB    | #########6                            |  26%
#
#
# bokeh-3.8.0          | 5.8 MB    | #####9                                |  16%
# matplotlib-base-3.10 | 7.9 MB    | ###########8                          |  32%
#
#
# bokeh-3.8.0          | 5.8 MB    | #######4                              |  20%
#
# numpy-base-2.3.3     | 6.2 MB    | ########8                             |  24%
#
#
# pandas-2.3.2         | 14.1 MB   | ###5                                  |  10%
# matplotlib-base-3.10 | 7.9 MB    | ############6                         |  34%
#
# numpy-base-2.3.3     | 6.2 MB    | #########8                            |  27%
# matplotlib-base-3.10 | 7.9 MB    | #############9                        |  38%
#
#
# bokeh-3.8.0          | 5.8 MB    | #########1                            |  25%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | 5                                     |   2%
#
# pandas-2.3.2         | 14.1 MB   | ###9                                  |  11%
# matplotlib-base-3.10 | 7.9 MB    | ##############7                       |  40%
#
#
# pandas-2.3.2         | 14.1 MB   | ####4                                 |  12%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | 9                                     |   3%
#
# numpy-base-2.3.3     | 6.2 MB    | ###########3                          |  31%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | ######4                               |  17%
# matplotlib-base-3.10 | 7.9 MB    | ################                      |  43%
#
#
# pandas-2.3.2         | 14.1 MB   | ####8                                 |  13%
#
# numpy-base-2.3.3     | 6.2 MB    | ############                          |  33%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | ##########7                           |  29%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##########9                           |  30%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | #############8                        |  37%
# pandas-2.3.2         | 14.1 MB   | #####2                                |  14%
#
# numpy-base-2.3.3     | 6.2 MB    | ############7                         |  34%
#
#
# bokeh-3.8.0          | 5.8 MB    | ###########4                          |  31%
#
#
#
# pandas-2.3.2         | 14.1 MB   | #####5                                |  15%
# matplotlib-base-3.10 | 7.9 MB    | ##################                    |  49%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | ####################1                 |  54%
#
#
# bokeh-3.8.0          | 5.8 MB    | ############                          |  33%
#
# numpy-base-2.3.3     | 6.2 MB    | #############2                        |  36%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | ######################7               |  62%
#
#
# pandas-2.3.2         | 14.1 MB   | #####7                                |  16%
# matplotlib-base-3.10 | 7.9 MB    | ##################6                   |  50%
#
# numpy-base-2.3.3     | 6.2 MB    | #############7                        |  37%
#
#
#
# pandas-2.3.2         | 14.1 MB   | ######                                |  16%
#
# numpy-base-2.3.3     | 6.2 MB    | ##############1                       |  38%
#
#
# bokeh-3.8.0          | 5.8 MB    | #############3                        |  36%
# matplotlib-base-3.10 | 7.9 MB    | ###################1                  |  52%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | ##################################### | 100%
#
#
#
# libopenblas-0.3.30   | 4.1 MB    | ##################################### | 100%
#
#
#
# pandas-2.3.2         | 14.1 MB   | ######3                               |  17%
#
# numpy-base-2.3.3     | 6.2 MB    | ##############8                       |  40%
# matplotlib-base-3.10 | 7.9 MB    | ####################3                 |  55%
#
#
# pandas-2.3.2         | 14.1 MB   | ######6                               |  18%
# matplotlib-base-3.10 | 7.9 MB    | ####################9                 |  57%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##############3                       |  39%
#
# numpy-base-2.3.3     | 6.2 MB    | ###############3                      |  41%
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ######8                               |  19%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##############7                       |  40%
# matplotlib-base-3.10 | 7.9 MB    | #####################5                |  58%
#
# numpy-base-2.3.3     | 6.2 MB    | ###############6                      |  42%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    | ####                                  |  11%
#
#
# bokeh-3.8.0          | 5.8 MB    | ###############7                      |  43%
# pandas-2.3.2         | 14.1 MB   | #######6                              |  21%
#
# numpy-base-2.3.3     | 6.2 MB    | ################6                     |  45%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    | #############4                        |  36%
# matplotlib-base-3.10 | 7.9 MB    | #######################7              |  64%
# matplotlib-base-3.10 | 7.9 MB    | ########################4             |  66%
#
#
# pandas-2.3.2         | 14.1 MB   | #######9                              |  21%
#
# numpy-base-2.3.3     | 6.2 MB    | #################1                    |  46%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    | #################8                    |  48%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    | ########################1             |  65%
#
#
# bokeh-3.8.0          | 5.8 MB    | #################2                    |  47%
#
# pandas-2.3.2         | 14.1 MB   | ########3                             |  23%
# matplotlib-base-3.10 | 7.9 MB    | #########################1            |  68%
# pandas-2.3.2         | 14.1 MB   | ########6                             |  23%
#
# numpy-base-2.3.3     | 6.2 MB    | ##################4                   |  50%
#
#
# bokeh-3.8.0          | 5.8 MB    | #################7                    |  48%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    | ###########################8          |  75%
# pandas-2.3.2         | 14.1 MB   | ########9                             |  24%
#
# numpy-base-2.3.3     | 6.2 MB    | ##################8                   |  51%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##################2                   |  49%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    | ##############################8       |  83%
# pandas-2.3.2         | 14.1 MB   | #########1                            |  25%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##################7                   |  51%
#
# numpy-base-2.3.3     | 6.2 MB    | ###################3                  |  52%
# matplotlib-base-3.10 | 7.9 MB    | ###########################1          |  73%
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | #########4                            |  25%
#
#
# bokeh-3.8.0          | 5.8 MB    | ###################2                  |  52%
#
# numpy-base-2.3.3     | 6.2 MB    | ###################8                  |  54%
# matplotlib-base-3.10 | 7.9 MB    | ###########################7          |  75%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    | ##################################### | 100%
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | #########8                            |  27%
#
# numpy-base-2.3.3     | 6.2 MB    | ####################3                 |  55%
#
#
# bokeh-3.8.0          | 5.8 MB    | ###################8                  |  54%
# matplotlib-base-3.10 | 7.9 MB    | ############################7         |  78%
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ##########3                           |  28%
#
#
# bokeh-3.8.0          | 5.8 MB    | ####################8                 |  56%
#
# numpy-base-2.3.3     | 6.2 MB    | #####################2                |  58%
# matplotlib-base-3.10 | 7.9 MB    | #############################5        |  80%
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ##########7                           |  29%
#
#
# bokeh-3.8.0          | 5.8 MB    | #####################4                |  58%
#
# numpy-base-2.3.3     | 6.2 MB    | #####################8                |  59%
#
#
#
#
#
# tornado-6.5.1        | 904 KB    | ##################################### | 100%
#
#
#
#
#
# tornado-6.5.1        | 904 KB    | ##################################### | 100%
# matplotlib-base-3.10 | 7.9 MB    | ##############################1       |  82%
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ###########                           |  30%
#
#
# bokeh-3.8.0          | 5.8 MB    | ######################                |  60%
#
# numpy-base-2.3.3     | 6.2 MB    | ######################4               |  61%
#
#
#
#
# fonttools-4.59.2     | 4.0 MB    | ##################################### | 100%
# matplotlib-base-3.10 | 7.9 MB    | ##############################9       |  84%
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ###########3                          |  31%
#
#
# bokeh-3.8.0          | 5.8 MB    | ######################5               |  61%
#
# numpy-base-2.3.3     | 6.2 MB    | ######################9               |  62%
# matplotlib-base-3.10 | 7.9 MB    | ###############################4      |  85%
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ###########6                          |  32%
#
#
# bokeh-3.8.0          | 5.8 MB    | #######################               |  62%
#
# numpy-base-2.3.3     | 6.2 MB    | #######################5              |  64%
#
#
#
#
#
#
# seaborn-0.13.2       | 726 KB    | ###########################7          |  75%
# pandas-2.3.2         | 14.1 MB   | ###########9                          |  32%
#
#
# bokeh-3.8.0          | 5.8 MB    | #######################7              |  64%
#
#
#
#
#
#
# seaborn-0.13.2       | 726 KB    | ##################################### | 100%
#
# numpy-base-2.3.3     | 6.2 MB    | ########################5             |  66%
#
#
#
#
#
#
# seaborn-0.13.2       | 726 KB    | ##################################### | 100%
# pandas-2.3.2         | 14.1 MB   | ############4                         |  34%
#
#
# bokeh-3.8.0          | 5.8 MB    | ########################4             |  66%
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ############7                         |  35%
#
#
#
#
#
#
#
# narwhals-1.31.0      | 587 KB    | ################1                     |  44%
#
#
# bokeh-3.8.0          | 5.8 MB    | #########################             |  68%
# matplotlib-base-3.10 | 7.9 MB    | #################################6    |  91%
#
# pandas-2.3.2         | 14.1 MB   | #############1                        |  36%
#
#
#
#
#
#
#
# narwhals-1.31.0      | 587 KB    | #############################2        |  79%
# matplotlib-base-3.10 | 7.9 MB    | ##################################3   |  93%
#
# numpy-base-2.3.3     | 6.2 MB    | #########################8            |  70%
#
#
# bokeh-3.8.0          | 5.8 MB    | #########################7            |  70%
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | #############4                        |  36%
#
#
#
#
#
#
#
# narwhals-1.31.0      | 587 KB    | ##################################### | 100%
# matplotlib-base-3.10 | 7.9 MB    | ##################################8   |  94%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##########################2           |  71%
#
# pandas-2.3.2         | 14.1 MB   | #############7                        |  37%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##########################6           |  72%
# matplotlib-base-3.10 | 7.9 MB    | ###################################2  |  95%
#
# numpy-base-2.3.3     | 6.2 MB    | ##########################9           |  73%
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ##############3                       |  39%
# matplotlib-base-3.10 | 7.9 MB    | ####################################2 |  98%
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 460 KB    | ###########################           |  73%
#
#
# bokeh-3.8.0          | 5.8 MB    | ###########################6          |  75%
#
# numpy-base-2.3.3     | 6.2 MB    | ###########################8          |  75%
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 460 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ##############6                       |  40%
# matplotlib-base-3.10 | 7.9 MB    | ####################################7 |  99%
#
#
# bokeh-3.8.0          | 5.8 MB    | ############################1         |  76%
#
# numpy-base-2.3.3     | 6.2 MB    | ############################3         |  77%
# matplotlib-base-3.10 | 7.9 MB    | ##################################### | 100%
#
#
# pandas-2.3.2         | 14.1 MB   | ##############9                       |  40%
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 455 KB    | #3                                    |   4%
#
# numpy-base-2.3.3     | 6.2 MB    | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.6         | 370 KB    | #6                                    |   4%
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 455 KB    | ################################5     |  88%
#
#
# bokeh-3.8.0          | 5.8 MB    | #############################4        |  80%
# pandas-2.3.2         | 14.1 MB   | ###############3                      |  42%
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 455 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 455 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.6         | 370 KB    | ########                              |  22%
#
#
# bokeh-3.8.0          | 5.8 MB    | #############################9        |  81%
#
# pandas-2.3.2         | 14.1 MB   | ###############7                      |  43%
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 367 KB    | #6                                    |   4%
#
# numpy-base-2.3.3     | 6.2 MB    | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.6         | 370 KB    | ###########################2          |  74%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.6         | 370 KB    | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 367 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.6         | 370 KB    | ##################################### | 100%
#
#
# bokeh-3.8.0          | 5.8 MB    | ###############################2      |  85%
#
# numpy-base-2.3.3     | 6.2 MB    | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 367 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ################6                     |  45%
#
# numpy-base-2.3.3     | 6.2 MB    | ################################      |  87%
#
#
# bokeh-3.8.0          | 5.8 MB    | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 265 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | #################                     |  46%
#
# numpy-base-2.3.3     | 6.2 MB    | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 265 KB    | ###############6                      |  42%
#
#
# bokeh-3.8.0          | 5.8 MB    | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | #################3                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 306 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 306 KB    | ##################################### | 100%
#
# numpy-base-2.3.3     | 6.2 MB    | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 265 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 265 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 265 KB    | ##################################### | 100%
#
#
# pandas-2.3.2         | 14.1 MB   | #################7                    |  48%
#
# numpy-base-2.3.3     | 6.2 MB    | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ##################1                   |  49%
#
#
# bokeh-3.8.0          | 5.8 MB    | #################################8    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 225 KB    | ##6                                   |   7%
#
# numpy-base-2.3.3     | 6.2 MB    | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 225 KB    | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2025.2          | 238 KB    | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2025.2          | 238 KB    | ################################3     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2025.2          | 238 KB    | ##################################### | 100%
#
#
# pandas-2.3.2         | 14.1 MB   | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 225 KB    | ##########################3           |  71%
#
# numpy-base-2.3.3     | 6.2 MB    | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 225 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 225 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9f              | 220 KB    | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ###################1                  |  52%
#
#
# bokeh-3.8.0          | 5.8 MB    | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 200 KB    | ##9                                   |   8%
#
# numpy-base-2.3.3     | 6.2 MB    | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9f              | 220 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9f              | 220 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ###################5                  |  53%
#
# numpy-base-2.3.3     | 6.2 MB    | ##################################### | 100%
#
#
# bokeh-3.8.0          | 5.8 MB    | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.11.0       | 191 KB    | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 200 KB    | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 200 KB    | ##################################### | 100%
#
#
# pandas-2.3.2         | 14.1 MB   | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.11.0       | 191 KB    | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.11.0       | 191 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0.2         | 200 KB    | ##################################### | 100%
#
#
# bokeh-3.8.0          | 5.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.11.0       | 191 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ####################5                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yaml-0.2.5           | 71 KB     | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yaml-0.2.5           | 71 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yaml-0.2.5           | 71 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-tzdata-2025.2 | 141 KB    | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-tzdata-2025.2 | 141 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bottleneck-1.4.2     | 125 KB    | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | #####################3                |  58% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bottleneck-1.4.2     | 125 KB    | ##################################### | 100%
#
# numpy-base-2.3.3     | 6.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bottleneck-1.4.2     | 125 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.2         | 14.1 MB   | ######################8               |  62%
#
#
# pandas-2.3.2         | 14.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Add kernel

#conda activate py310
#python -m ipykernel install --user --name="py310"
